# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
# symbols = ['IBM','MSFT','META','INTC','NEM','AU','AEM','GFI','AAPL','TSLA','PG','ZS','ADSK','QLYS']

symbols = ['TSLA','META','GOOG','MSFT','AAPL']

max_date = 2020-1-1
today = 2022-11-30
data = f"yf.download(symbols, start= '{max_date}', end='{today}')"

# data = yf.download(symbols, start= "2020-01-01", end="2022-11-30")



# data = data['Adj Close']
print(data)

# portfolio_returns = data['Adj Close'].pct_change().dropna()

# print(portfolio_returns)
# Out:
# yf.download(symbols, start= '2018', end='1981')

# %%
portfolio_returns
# Out:
#                 AAPL      GOOG      META      MSFT      TSLA
# Date
# 2020-01-03 -0.009722 -0.004907 -0.005291 -0.012452  0.029633
# 2020-01-06  0.007968  0.024657  0.018834  0.002585  0.019255
# 2020-01-07 -0.004703 -0.000624  0.002164 -0.009118  0.038801
# 2020-01-08  0.016086  0.007880  0.010138  0.015928  0.049205
# 2020-01-09  0.021241  0.011044  0.014311  0.012493 -0.021945
# ...              ...       ...       ...       ...       ...
# 2022-11-22  0.014661  0.015653  0.014382  0.012311  0.012152
# 2022-11-23  0.005926  0.015309  0.007179  0.010407  0.078218
# 2022-11-25 -0.019594 -0.012346 -0.007395 -0.000364 -0.001856
# 2022-11-28 -0.026264 -0.013832 -0.023607 -0.023152  0.000328
# 2022-11-29 -0.021148 -0.008416  0.006251 -0.005915 -0.011426
#
# [733 rows x 5 columns]

# %%
portfolio_returns.plot(label='META', color=['orange', 'green','blue','yellow','red'],linewidth=2)

# plt.plot(portfolio_returns,linewidth=2,)


# Add a title and axis labels
plt.title('Percentage Price Change')

plt.xlabel('Date')
plt.ylabel('% Price Change')

# Change the size of the plot
plt.rcParams["figure.figsize"] = (15,8)



# Add a legend
plt.legend(fontsize = 15)

# Show the plot
plt.show()

# %%
from datetime import datetime

date_added = datetime.now().strftime('%Y-%m-%d')
date_added
# Out:
# '2022-12-29'
